# %% [markdown]
# #### Group project
# #### Date:  Nov 11, 2024
# #### Class: MIS 740 - Professor Hu
# #### Description: Clark County Meeting Room Inventory
# #### Author: Keith Webster

# %%
# import libraries and modules
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 20)
# read csv files and load into dataframe
df2 = pd.read_csv('/Users/keithpwebster/Desktop/UNLV MS APPLIED ECON DATA ANALYTICS/MIS 740/Group Project/Meeting_Space.csv')
# Inspect the data and dataframe
#df2.head()

# %%
# Inspect the dataframe and look for NaN
#df2.info()
#df2.columns
#df2.isna().sum()
# Change the display options
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 15)

# %%
#Change column type
df2.index.set_names('Property Count', inplace=True)
# Add columns to datafram
df2['City'] = 'Las Vegas'
# Add a state column with value set to NV
df2['State'] = 'NV'

# %%
# Meeting Space Calculator and Recommendation Engine for Las Vegas Events
print('Meeting Space Calculator and Recommendation Engine for Las Vegas Events')
print('')

# Function to get a valid integer input
def get_valid_integer(prompt):
    while True:
        user_input = input(prompt)
        if user_input.isdigit():  # Check if the input is a digit
            return int(user_input)  # Convert to integer and return
        else:
            print("Invalid input. Please enter a valid number.")

# Get number of attendees
attendees = get_valid_integer('Please enter the estimated number of attendees at your event: ')

# Get number of hotel rooms required
rooms = get_valid_integer('Please enter the number of hotel rooms required for your event: ')

# Get minimum space required
space_min = get_valid_integer('Please enter the minimum space required (sq. ft) for your meeting: ')

# Get maximum space required
space_max = get_valid_integer('Please enter the maximum space required (sq. ft) for your meeting: ')

# Display the inputs back to the user
print("\nEvent Details:")
print(f"Estimated Attendees: {attendees}")
print(f"Hotel Rooms Required: {rooms}")
print(f"Meeting Space Required: {space_min} - {space_max} sq. ft")
# Out:
# Meeting Space Calculator and Recommendation Engine for Las Vegas Events
# Please enter the estimated number of attendees at your event:  500
# Please enter the number of hotel rooms required for your event:  300
# Please enter the minimum space required (sq. ft) for your meeting:  20000
# Please enter the maximum space required (sq. ft) for your meeting:  50000
# Event Details:
# Estimated Attendees: 500
# Hotel Rooms Required: 300
# Meeting Space Required: 20000 - 50000 sq. ft

# %%
# convert dataframe columns to integer and address comma seperator
df2['Hotel Room Inventory'] = df2['Hotel Room Inventory'].str.split(',').str.join('').astype(int)
df2['Exhibit Meeting Area'] = df2['Exhibit Meeting Area'].str.split(',').str.join('').astype(int)

# %%
# Create boolean mask with user input
mask_area = (df2['Exhibit Meeting Area'] >= int(space_min)) & (df2['Exhibit Meeting Area'] <= int(space_max))
mask_room = (df2['Hotel Room Inventory'] >= int(rooms))

# %%
# Show results of boolean masking on user input
df3 = df2.loc[mask_area]
df4 = df3.loc[mask_room]

# %%
print('----------------------- Vegas IQ ---------------------------')
print('')
print('The following meeting venues match your search requirements')
print('')
print('Hotel rooms required:                  '+str(rooms))
print('Exhibit space min (sq.ft.) required:   '+str(space_min))
print('Exhibit space max (sq.ft.) required:   '+str(space_max))
df_final = df4[['Property', 'City', 'State', 'Exhibit Meeting Area', 'Hotel Room Inventory']]
# Display the datafram and hide the index
df_final.style.hide()
# Out:
# ----------------------- Vegas IQ ---------------------------
#
# The following meeting venues match your search requirements
#
# Hotel rooms required:                  300
# Exhibit space min (sq.ft.) required:   20000
# Exhibit space max (sq.ft.) required:   50000
# <style type="text/css">
# </style>
# <table id="T_2936e">
#   <thead>
#     <tr>
#       <th id="T_2936e_level0_col0" class="col_heading level0 col0" >Property</th>
#       <th id="T_2936e_level0_col1" class="col_heading level0 col1" >City</th>
#       <th id="T_2936e_level0_col2" class="col_heading level0 col2" >State</th>
#       <th id="T_2936e_level0_col3" class="col_heading level0 col3" >Exhibit Meeting Area</th>
#       <th id="T_2936e_level0_col4" class="col_heading level0 col4" >Hotel Room Inventory</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2936e_row0_col0" class="data row0 col0" >Alexis Park All Suite Resort</td>
#       <td id="T_2936e_row0_col1" class="data row0 col1" >Las Vegas</td>
#       <td id="T_2936e_row0_col2" class="data row0 col2" >NV</td>
#       <td id="T_2936e_row0_col3" class="data row0 col3" >50000</td>
#       <td id="T_2936e_row0_col4" class="data row0 col4" >496</td>
#     </tr>
#     <tr>
#       <td id="T_2936e_row1_col0" class="data row1 col0" >Circa Resort & Casino</td>
#       <td id="T_2936e_row1_col1" class="data row1 col1" >Las Vegas</td>
#       <td id="T_2936e_row1_col2" class="data row1 col2" >NV</td>
#       <td id="T_2936e_row1_col3" class="data row1 col3" >33000</td>
#       <td id="T_2936e_row1_col4" class="data row1 col4" >512</td>
#     </tr>
#     <tr>
#       <td id="T_2936e_row2_col0" class="data row2 col0" >Downtown Grand Hotel & Casino</td>
#       <td id="T_2936e_row2_col1" class="data row2 col1" >Las Vegas</td>
#       <td id="T_2936e_row2_col2" class="data row2 col2" >NV</td>
#       <td id="T_2936e_row2_col3" class="data row2 col3" >46674</td>
#       <td id="T_2936e_row2_col4" class="data row2 col4" >1124</td>
#     </tr>
#     <tr>
#       <td id="T_2936e_row3_col0" class="data row3 col0" >Four Seasons Hotel Las Vegas</td>
#       <td id="T_2936e_row3_col1" class="data row3 col1" >Las Vegas</td>
#       <td id="T_2936e_row3_col2" class="data row3 col2" >NV</td>
#       <td id="T_2936e_row3_col3" class="data row3 col3" >30000</td>
#       <td id="T_2936e_row3_col4" class="data row3 col4" >424</td>
#     </tr>
#     <tr>
#       <td id="T_2936e_row4_col0" class="data row4 col0" >Gold Coast Hotel and Casino</td>
#       <td id="T_2936e_row4_col1" class="data row4 col1" >Las Vegas</td>
#       <td id="T_2936e_row4_col2" class="data row4 col2" >NV</td>
#       <td id="T_2936e_row4_col3" class="data row4 col3" >30000</td>
#       <td id="T_2936e_row4_col4" class="data row4 col4" >705</td>
#     </tr>
#     <tr>
#       <td id="T_2936e_row5_col0" class="data row5 col0" >Golden Nugget</td>
#       <td id="T_2936e_row5_col1" class="data row5 col1" >Las Vegas</td>
#       <td id="T_2936e_row5_col2" class="data row5 col2" >NV</td>
#       <td id="T_2936e_row5_col3" class="data row5 col3" >40000</td>
#       <td id="T_2936e_row5_col4" class="data row5 col4" >2419</td>
#     </tr>
#     <tr>
#       <td id="T_2936e_row6_col0" class="data row6 col0" >Harrah's Las Vegas</td>
#       <td id="T_2936e_row6_col1" class="data row6 col1" >Las Vegas</td>
#       <td id="T_2936e_row6_col2" class="data row6 col2" >NV</td>
#       <td id="T_2936e_row6_col3" class="data row6 col3" >25000</td>
#       <td id="T_2936e_row6_col4" class="data row6 col4" >2541</td>
#     </tr>
#     <tr>
#       <td id="T_2936e_row7_col0" class="data row7 col0" >Luxor Hotel and Casino</td>
#       <td id="T_2936e_row7_col1" class="data row7 col1" >Las Vegas</td>
#       <td id="T_2936e_row7_col2" class="data row7 col2" >NV</td>
#       <td id="T_2936e_row7_col3" class="data row7 col3" >41000</td>
#       <td id="T_2936e_row7_col4" class="data row7 col4" >4400</td>
#     </tr>
#     <tr>
#       <td id="T_2936e_row8_col0" class="data row8 col0" >New York-New York Hotel & Casino</td>
#       <td id="T_2936e_row8_col1" class="data row8 col1" >Las Vegas</td>
#       <td id="T_2936e_row8_col2" class="data row8 col2" >NV</td>
#       <td id="T_2936e_row8_col3" class="data row8 col3" >21500</td>
#       <td id="T_2936e_row8_col4" class="data row8 col4" >2024</td>
#     </tr>
#     <tr>
#       <td id="T_2936e_row9_col0" class="data row9 col0" >OYO Hotel & Casino Las Vegas</td>
#       <td id="T_2936e_row9_col1" class="data row9 col1" >Las Vegas</td>
#       <td id="T_2936e_row9_col2" class="data row9 col2" >NV</td>
#       <td id="T_2936e_row9_col3" class="data row9 col3" >38500</td>
#       <td id="T_2936e_row9_col4" class="data row9 col4" >657</td>
#     </tr>
#     <tr>
#       <td id="T_2936e_row10_col0" class="data row10 col0" >Plaza Hotel & Casino</td>
#       <td id="T_2936e_row10_col1" class="data row10 col1" >Las Vegas</td>
#       <td id="T_2936e_row10_col2" class="data row10 col2" >NV</td>
#       <td id="T_2936e_row10_col3" class="data row10 col3" >43482</td>
#       <td id="T_2936e_row10_col4" class="data row10 col4" >995</td>
#     </tr>
#     <tr>
#       <td id="T_2936e_row11_col0" class="data row11 col0" >Renaissance Las Vegas Hotel</td>
#       <td id="T_2936e_row11_col1" class="data row11 col1" >Las Vegas</td>
#       <td id="T_2936e_row11_col2" class="data row11 col2" >NV</td>
#       <td id="T_2936e_row11_col3" class="data row11 col3" >20000</td>
#       <td id="T_2936e_row11_col4" class="data row11 col4" >548</td>
#     </tr>
#     <tr>
#       <td id="T_2936e_row12_col0" class="data row12 col0" >Sam's Town Hotel and Gambling Hall</td>
#       <td id="T_2936e_row12_col1" class="data row12 col1" >Las Vegas</td>
#       <td id="T_2936e_row12_col2" class="data row12 col2" >NV</td>
#       <td id="T_2936e_row12_col3" class="data row12 col3" >30000</td>
#       <td id="T_2936e_row12_col4" class="data row12 col4" >645</td>
#     </tr>
#     <tr>
#       <td id="T_2936e_row13_col0" class="data row13 col0" >Suncoast Hotel and Casino</td>
#       <td id="T_2936e_row13_col1" class="data row13 col1" >Las Vegas</td>
#       <td id="T_2936e_row13_col2" class="data row13 col2" >NV</td>
#       <td id="T_2936e_row13_col3" class="data row13 col3" >25000</td>
#       <td id="T_2936e_row13_col4" class="data row13 col4" >427</td>
#     </tr>
#     <tr>
#       <td id="T_2936e_row14_col0" class="data row14 col0" >Treasure Island — Tl Hotel & Casino, a Radisson Hotel</td>
#       <td id="T_2936e_row14_col1" class="data row14 col1" >Las Vegas</td>
#       <td id="T_2936e_row14_col2" class="data row14 col2" >NV</td>
#       <td id="T_2936e_row14_col3" class="data row14 col3" >23500</td>
#       <td id="T_2936e_row14_col4" class="data row14 col4" >2884</td>
#     </tr>
#     <tr>
#       <td id="T_2936e_row15_col0" class="data row15 col0" >Tuscany Suites & Casino</td>
#       <td id="T_2936e_row15_col1" class="data row15 col1" >Las Vegas</td>
#       <td id="T_2936e_row15_col2" class="data row15 col2" >NV</td>
#       <td id="T_2936e_row15_col3" class="data row15 col3" >40000</td>
#       <td id="T_2936e_row15_col4" class="data row15 col4" >716</td>
#     </tr>
#     <tr>
#       <td id="T_2936e_row16_col0" class="data row16 col0" >The Westin Lake Las Vegas Resort & Spa</td>
#       <td id="T_2936e_row16_col1" class="data row16 col1" >Las Vegas</td>
#       <td id="T_2936e_row16_col2" class="data row16 col2" >NV</td>
#       <td id="T_2936e_row16_col3" class="data row16 col3" >45000</td>
#       <td id="T_2936e_row16_col4" class="data row16 col4" >493</td>
#     </tr>
#     <tr>
#       <td id="T_2936e_row17_col0" class="data row17 col0" >The Westin Las Vegas Hotel & Spa</td>
#       <td id="T_2936e_row17_col1" class="data row17 col1" >Las Vegas</td>
#       <td id="T_2936e_row17_col2" class="data row17 col2" >NV</td>
#       <td id="T_2936e_row17_col3" class="data row17 col3" >25000</td>
#       <td id="T_2936e_row17_col4" class="data row17 col4" >826</td>
#     </tr>
#     <tr>
#       <td id="T_2936e_row18_col0" class="data row18 col0" >Buffalo Bill's Resort and Casino</td>
#       <td id="T_2936e_row18_col1" class="data row18 col1" >Las Vegas</td>
#       <td id="T_2936e_row18_col2" class="data row18 col2" >NV</td>
#       <td id="T_2936e_row18_col3" class="data row18 col3" >31280</td>
#       <td id="T_2936e_row18_col4" class="data row18 col4" >1232</td>
#     </tr>
#     <tr>
#       <td id="T_2936e_row19_col0" class="data row19 col0" >Primm Valley Resort and Casino</td>
#       <td id="T_2936e_row19_col
