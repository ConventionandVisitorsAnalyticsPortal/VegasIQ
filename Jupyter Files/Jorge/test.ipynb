# %%
from IPython.display import clear_output

def menu():
    while True:
        clear_output(wait=True)  # Clears the output
        print("Menu:")
        print("1. Option 1")
        print("2. Option 2")
        print("3. Exit")
        choice = input("Please enter your choice: ")
        
        if choice == "1":
            print("You selected Option 1!")
            input("Press Enter to continue...")  # Wait before clearing the screen
        elif choice == "2":
            print("You selected Option 2!")
            input("Press Enter to continue...")  # Wait before clearing the screen
        elif choice == "3":
            print("Exiting...")
            break
        else:
            print("Invalid choice! Please try again.")
            input("Press Enter to continue...")  # Wait before clearing the screen
        


menu()
# Out:
# Menu:
# 1. Option 1
# 2. Option 2
# 3. Exit

# %% [markdown]
# # 1

# %%
```````````````````
