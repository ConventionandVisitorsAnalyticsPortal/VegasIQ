# %%
import pandas as pd  # Import the Pandas library for data manipulation

class RoomInventory:
    def __init__(self,file_path):
        # Use pandas to read the CSV file and load it into a DataFrame
        self.hotel_df = pd.read_csv(Downloads/Clark_County_Room_Inventory_Dec_2023.csv)  # Use the provided file_path parameter

    def display_inventory(self):
        # Display the first few rows of the DataFrame to show room inventory
        print(self.hotel_df.head())

    def search_hotel(self, hotel_name):
        # Search for the hotel by name using a helper function
        result = self.case_insensitive_search(hotel_name)
        if not result.empty:
            print(result)
        else:
            print("No hotel found with that name.")

    def case_insensitive_search(self, hotel_name):
        # Perform a case-insensitive search for the hotel name
        return self.hotel_df[self.hotel_df['Property Name'].str.contains(hotel_name)]

    def check_room_availability(self, hotel_name, rooms_needed):
        # Search for hotel
        hotel = self.case_insensitive_search(hotel_name)
        
        if hotel.empty:
            print(f"No hotel found with name: {hotel_name}")
        else:
            # Check room inventory availability, ensuring 'Rooms' is a numerical type
            available_rooms = hotel['Rooms'].values[0]
            if available_rooms >= rooms_needed:
                print(f"Rooms available in {hotel_name}: {available_rooms}")
            else:
                print(f"Not enough rooms available in {hotel_name}. Needed: {rooms_needed}, Available: {available_rooms}")


def main():
    # Path to the CSV file
    file_path = "Downloads/Clark_County_Room_Inventory_Dec_2023.csv"

    # Initialize the RoomInventory class with the file path
    room_inventory = RoomInventory(file_path)

    # Display the room inventory data
    room_inventory.display_inventory()

    # Example search for a hotel
    hotel_name = input("Enter hotel name to search: ")
    room_inventory.search_hotel(hotel_name)

    # Example check for room availability
    rooms_needed = int(input("Enter number of rooms needed: "))
    room_inventory.check_room_availability(hotel_name, rooms_needed)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 58
#      55     room_inventory.check_room_availability(hotel_name, rooms_needed)
#      57 if __name__ == "__main__":
# ---> 58     main()
#
# Cell In[6], line 44, in main()
#      41 file_path = "Downloads/Clark_County_Room_Inventory_Dec_2023.csv"
#      43 # Initialize the RoomInventory class with the file path
# ---> 44 room_inventory = RoomInventory(file_path)
#      46 # Display the room inventory data
#      47 room_inventory.display_inventory()
#
# Cell In[6], line 6, in RoomInventory.__init__(self, file_path)
#       4 def __init__(self,file_path):
#       5     # Use pandas to read the CSV file and load it into a DataFrame
# ----> 6     self.hotel_df = pd.read_csv(Downloads/Clark_County_Room_Inventory_Dec_2023.csv)
#
# NameError: name 'Downloads' is not defined

# %%
import pandas as pd  # Import the Pandas library for data manipulation

class RoomInventory:
    def __init__(self,'file_path'):
        # Use pandas to read the CSV file and load it into a DataFrame
        self.hotel_df = pd.read_csv(Downloads/Clark_County_Room_Inventory_Dec_2023.csv)  # Use the provided file_path parameter

    def display_inventory(self):
        # Display the first few rows of the DataFrame to show room inventory
        print(self.hotel_df.head())

    def search_hotel(self, hotel_name):
        # Search for the hotel by name using a helper function
        result = self.case_insensitive_search(hotel_name)
        if not result.empty:
            print(result)
        else:
            print("No hotel found with that name.")

    def case_insensitive_search(self, hotel_name):
        # Perform a case-insensitive search for the hotel name
        return self.hotel_df[self.hotel_df['Property Name'].str.contains(hotel_name)]

    def check_room_availability(self, hotel_name, rooms_needed):
        # Search for hotel
        hotel = self.case_insensitive_search(hotel_name)
        
        if hotel.empty:
            print(f"No hotel found with name: {hotel_name}")
        else:
            # Check room inventory availability, ensuring 'Rooms' is a numerical type
            available_rooms = hotel['Rooms'].values[0]
            if available_rooms >= rooms_needed:
                print(f"Rooms available in {hotel_name}: {available_rooms}")
            else:
                print(f"Not enough rooms available in {hotel_name}. Needed: {rooms_needed}, Available: {available_rooms}")


def main():
    # Path to the CSV file
    file_path = "Downloads/Clark_County_Room_Inventory_Dec_2023 (1).csv"

    # Initialize the RoomInventory class with the file path
    room_inventory = RoomInventory(file_path)

    # Display the room inventory data
    room_inventory.display_inventory()

    # Example search for a hotel
    hotel_name = input("Enter hotel name to search: ")
    room_inventory.search_hotel(hotel_name)

    # Example check for room availability
    rooms_needed = int(input("Enter number of rooms needed: "))
    room_inventory.check_room_availability(hotel_name, rooms_needed)

if __name__ == "__main__":
    main()
# Out:
#   Cell In[4], line 4
#     def __init__(self,'file_path'):
#                       ^
# SyntaxError: invalid syntax
